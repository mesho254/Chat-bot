# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = {"Intents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["My name is Mesho," "How can I help you?"]
             }

]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in data["Intents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               
- accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6608e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7789e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1408e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.3164e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9371e-05 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.1889e-05 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1607e-06 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.5091e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3773e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4504e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.6312e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5035e-05 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8726e-06 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2978e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3456e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2206e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 16ms/step - loss: 8.0466e-07 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 15ms/step - loss: 9.7682e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.0789e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4227e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3271e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 14ms/step - loss: 4.5448e-06 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0812e-06 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8173e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.1872e-06 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4809e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1458e-06 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9653e-06 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4922e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5200e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8040e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.8138e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.6427e-07 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1621e-05 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0296e-05 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.9138e-05 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5191e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.5763e-07 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3395e-06 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4856e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0799e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5601e-05 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0339e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.8996e-05 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["Intents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, data)
    print(ourResult)
# Out:
# 1/1 [==============================] - 0s 223ms/step
# My name is Mesho,I'm Mesho
# 1/1 [==============================] - 0s 44ms/step
# Hi there
# 1/1 [==============================] - 0s 49ms/step
# Hello
# 1/1 [==============================] - 0s 56ms/step
# Hello
# 1/1 [==============================] - 0s 49ms/step
# Hi there
# 1/1 [==============================] - 0s 42ms/step
# Hello
# 1/1 [==============================] - 0s 45ms/step
# Hello
# 1/1 [==============================] - 0s 43ms/step
# Hello
# 1/1 [==============================] - 0s 45ms/step
# Hi :)
# 1/1 [==============================] - 0s 43ms/step
# Hello
# 1/1 [==============================] - 0s 45ms/step
# Hi there
# 1/1 [==============================] - 0s 53ms/step
# Hi there
# 1/1 [==============================] - 0s 62ms/step
# Hi there
# 1/1 [==============================] - 0s 43ms/step
# Hi there
# 1/1 [==============================] - 0s 44ms/step
# Hi :)
# 1/1 [==============================] - 0s 43ms/step
# Hi there
# 1/1 [==============================] - 0s 46ms/step
# Hi there
# 1/1 [==============================] - 0s 42ms/step
# Hi :)
# 1/1 [==============================] - 0s 46ms/step
# Hi there
# 1/1 [==============================] - 0s 49ms/step
# Hi :)
# 1/1 [==============================] - 0s 51ms/step
# Hi :)
# 1/1 [==============================] - 0s 42ms/step
# Hi :)
